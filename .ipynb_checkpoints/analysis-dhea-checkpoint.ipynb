# %%
import pandas as pd
import numpy as np
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('cleandate.csv')
data.head(5)
# Out:
#    course_id  price  num_subscribers  num_reviews  num_lectures  rating  \
# 0     695656    195            31499          450            46    0.76
# 1     511934      0            30531         1948            53    0.78
# 2     267560      0            29990         1342            87    0.95
# 3     866460    195            29348          780            66    0.31
# 4     151668      0            29167         1463             8    0.18
#
#    content_duration  level  subject  paid        Date
# 0               4.0      2        4     1  2015-12-29
# 1               3.0      1        4     0  2015-06-30
# 2              17.5      2        4     0  2014-08-10
# 3               3.0      2        4     1  2016-11-29
# 4               1.5      1        1     0  2014-05-27

# %%
data.dtypes
# Out:
# course_id             int64
# price                 int64
# num_subscribers       int64
# num_reviews           int64
# num_lectures          int64
# rating              float64
# content_duration    float64
# level                 int64
# subject               int64
# paid                  int64
# Date                 object
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# course_id                       int64
# course_title                   object
# url                            object
# price                           int64
# num_subscribers                 int64
# num_reviews                     int64
# num_lectures                    int64
# level                          object
# rating                        float64
# content_duration              float64
# published_timestamp            object
# subject                        object
# Date                   datetime64[ns]
# Free/Paid                      object
# dtype: object

# %%
a = sns.displot(data, x="subject")
a.set_xticklabels(rotation=45)
plt.show()

# %%
totals = []
dates = data.Date.unique()
dates.sort()
for i in dates:
    tempDF = data[data['Date']==i]
    totals.append([i,len(tempDF)])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(totals))],
            y=[i[1] for i in totals],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.title(label='Course uploads over time (Business + Web + Design + Music)')
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Number of uploads')
plt.xticks([])
plt.show()

# %%
data_web = data[data['subject']=='Web Development']
totals = []
dates = data_web.Date.unique()
dates.sort()
for i in dates:
    tempDF = data_web[data_web['Date']==i]
    totals.append([i,len(tempDF)])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(totals))],
            y=[i[1] for i in totals],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.title(label='Course uploads over time (Web Development)')
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Number of uploads')
plt.xticks([])
plt.show()

# %%
data_business = data[data['subject']=='Business Finance']
totals = []
dates = data_business.Date.unique()
dates.sort()
for i in dates:
    tempDF = data_business[data_business['Date']==i]
    totals.append([i,len(tempDF)])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(totals))],
            y=[i[1] for i in totals],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.title(label='Course uploads over time (Business Finance)')
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Number of uploads')
plt.xticks([])
plt.show()

# %%
data_music = data[data['subject']=='Musical Instruments']
totals = []
dates = data_music.Date.unique()
dates.sort()
for i in dates:
    tempDF = data_music[data_music['Date']==i]
    totals.append([i,len(tempDF)])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(totals))],
            y=[i[1] for i in totals],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.title(label='Course uploads over time (Musical Instruments)')
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Number of uploads')
plt.xticks([])
plt.show()

# %%
data_design = data[data['subject']=='Graphic Design']
totals = []
dates = data_design.Date.unique()
dates.sort()
for i in dates:
    tempDF = data_design[data_design['Date']==i]
    totals.append([i,len(tempDF)])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(totals))],
            y=[i[1] for i in totals],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.title(label='Course uploads over time (Graphic Design)')
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Number of uploads')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data[data.Date == i]
    sums.append([i,np.mean(tempDF['price'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average price')
plt.title(label='Changing average price for course uploaded to Udemy over time (Business + Web + Design + Music)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_web[data_web.Date == i]
    sums.append([i,np.mean(tempDF['price'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average price')
plt.title(label='Changing average price for course uploaded to Udemy over time (Web)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_business[data_business.Date == i]
    sums.append([i,np.mean(tempDF['price'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average price')
plt.title(label='Changing average price for course uploaded to Udemy over time (Business Finance)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_music[data_music.Date == i]
    sums.append([i,np.mean(tempDF['price'])])
print(sums[4])
print(sums[-1])

plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average price')
plt.title(label='Changing average price for course uploaded to Udemy over time (Musical Instruments)')
plt.xticks([])
plt.show()
# Out:
# [numpy.datetime64('2012-10-31T00:00:00.000000000'), 200.0]
# [numpy.datetime64('2017-07-06T00:00:00.000000000'), 20.0]

# %%
sums = []
for i in dates:
    tempDF= data_design[data_design.Date == i]
    sums.append([i,np.mean(tempDF['price'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average price')
plt.title(label='Changing average price for course uploaded to Udemy over time (Graphic Design)')
plt.xticks([])
plt.show()

# %%
data['num_subscribers'].mean()
# Out:
# 3199.260881392818

# %%
data_business['num_subscribers'].mean()
# Out:
# 1569.0268681780017

# %%
data_web['num_subscribers'].mean()
# Out:
# 6635.02493765586

# %%
data_design['num_subscribers'].mean()
# Out:
# 1766.0265780730897

# %%
data_music['num_subscribers'].mean()
# Out:
# 1245.1308823529412

# %%
num_subs = data.groupby(['subject', 'level', data['Date'].dt.year])['num_subscribers'].mean()
pd.set_option('display.max_rows', None)
print(num_subs)
# Out:
# subject              level               Date
# Business Finance     All Levels          2012      621.666667
#                                          2013     4597.297872
#                                          2014     2884.049020
#                                          2015     1508.627027
#                                          2016     1259.697674
#                                          2017      609.556452
#                      Beginner Level      2012       43.000000
#                                          2013     2811.187500
#                                          2014     2180.044118
#                                          2015     1412.454545
#                                          2016      992.512605
#                                          2017      381.130435
#                      Expert Level        2014     2304.250000
#                                          2015     2131.857143
#                                          2016      645.285714
#                                          2017      977.428571
#                      Intermediate Level  2012      856.000000
#                                          2013     1126.600000
#                                          2014     2388.333333
#                                          2015     1418.081081
#                                          2016     1782.714286
#                                          2017      938.000000
# Graphic Design       All Levels          2012    17781.000000
#                                          2013     1952.777778
#                                          2014     3479.363636
#                                          2015     2140.052083
#                                          2016     1605.266055
#                                          2017      952.465116
#                      Beginner Level      2012    12359.400000
#                                          2013     3428.000000
#                                          2014     2314.916667
#                                          2015     2450.795918
#                                          2016      717.122449
#                                          2017     1260.180000
#                      Expert Level        2013     1995.000000
#                                          2014      152.000000
#                                          2015     1004.500000
#                                          2017       28.000000
#                      Intermediate Level  2012     1096.666667
#                                          2013      914.400000
#                                          2014      650.166667
#                                          2015     1205.380952
#                                          2016      846.695652
#                                          2017      577.333333
# Musical Instruments  All Levels          2012    25720.000000
#                                          2013     6497.684211
#                                          2014      370.466667
#                                          2015     1259.091954
#                                          2016      565.682692
#                                          2017      456.897959
#                      Beginner Level      2012      916.333333
#                                          2013     1488.941176
#                                          2014     2609.127660
#                                          2015      705.932203
#                                          2016      654.957895
#                                          2017      688.222222
#                                          2014     382362
#                                          2015     915397
#                                          2016     902888
#                                          2017     222156
#                      Expert Level        2013     167191
#                                          2014      17282
#                                          2015       9681
#                                          2016      27374
#                                          2017        361
#                      Intermediate Level  2012       1758
#                                          2013      27184
#                                          2014     175982
#                                          2015     195249
#                                          2016     232425
#                                          2017      86466
# Name: num_subscribers, dtype: int64

# %%
sums = []
for i in dates:
    tempDF= data[data.Date == i]
    sums.append([i,np.mean(tempDF['num_subscribers'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average subscribers')
plt.title(label='Changing number of subscribers for course uploaded to Udemy over time (Business + Web + Design + Music)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_business[data_business.Date == i]
    sums.append([i,np.mean(tempDF['num_subscribers'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average subscribers')
plt.title(label='Changing number of subscribers for course uploaded to Udemy over time (Business)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_web[data_web.Date == i]
    sums.append([i,np.mean(tempDF['num_subscribers'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average subscribers')
plt.title(label='Changing number of subscribers for course uploaded to Udemy over time (Web)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_design[data_design.Date == i]
    sums.append([i,np.mean(tempDF['num_subscribers'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average subscribers')
plt.title(label='Changing number of subscribers for course uploaded to Udemy over time (Design)')
plt.xticks([])
plt.show()

# %%
sums = []
for i in dates:
    tempDF= data_music[data_music.Date == i]
    sums.append([i,np.mean(tempDF['num_subscribers'])])
plt.figure(figsize=(12,6))
sns.regplot(x=[i for i in range(len(sums))],
            y=[i[1] for i in sums],
            scatter_kws={'color': '#A435F0'}, line_kws={'color': '#199FA3'})
plt.xlabel(xlabel='Time (from 2011 to 2017)')
plt.ylabel(ylabel='Average subscribers')
plt.title(label='Changing number of subscribers for course uploaded to Udemy over time (Music)')
plt.xticks([])
plt.show()
